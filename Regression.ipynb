# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('nyc_temperature.csv')
data
# Out:
#          date  tmax  tmin  tavg  departure  HDD  CDD precipitation new_snow  \
# 0      1/1/19    60    40  50.0       13.9   15    0          0.08        0
# 1      2/1/19    41    35  38.0        2.1   27    0             0        0
# 2      3/1/19    45    39  42.0        6.3   23    0             T        0
# 3      4/1/19    47    37  42.0        6.5   23    0             0        0
# 4      5/1/19    47    42  44.5        9.1   20    0          0.45        0
# ..        ...   ...   ...   ...        ...  ...  ...           ...      ...
# 360  27/12/19    54    42  48.0       10.8   17    0             T        0
# 361  28/12/19    50    44  47.0       10.0   18    0             0        0
# 362  29/12/19    44    38  41.0        4.3   24    0          0.29        0
# 363  30/12/19    43    38  40.5        4.0   24    0          0.49        0
# 364  31/12/19    46    38  42.0        5.7   23    0          0.01        0
#
#     snow_depth
# 0            0
# 1            0
# ...

# %%
data.head()
# Out:
#      date  tmax  tmin  tavg  departure  HDD  CDD precipitation new_snow  \
# 0  1/1/19    60    40  50.0       13.9   15    0          0.08        0
# 1  2/1/19    41    35  38.0        2.1   27    0             0        0
# 2  3/1/19    45    39  42.0        6.3   23    0             T        0
# 3  4/1/19    47    37  42.0        6.5   23    0             0        0
# 4  5/1/19    47    42  44.5        9.1   20    0          0.45        0
#
#   snow_depth
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           365 non-null    object
#  1   tmax           365 non-null    int64
#  2   tmin           365 non-null    int64
#  3   tavg           365 non-null    float64
#  4   departure      365 non-null    float64
#  5   HDD            365 non-null    int64
#  6   CDD            365 non-null    int64
#  7   precipitation  365 non-null    object
#  8   new_snow       365 non-null    object
#  9   snow_depth     365 non-null    object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 28.6+ KB

# %%
data.columns
# Out:
# Index(['date', 'tmax', 'tmin', 'tavg', 'departure', 'HDD', 'CDD',
#        'precipitation', 'new_snow', 'snow_depth'],
#       dtype='object')

# %%
sns.pairplot(data)

# %%
sns.displot(data['tavg'])

# %%
sns.heatmap(data.corr())
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_24444\1794321463.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr())
# <AxesSubplot: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(data[['tmin','tmax']],data['tavg'])

linearmodel = LinearRegression()
linearmodel.fit(X_train,y_train)
linearPred = linearmodel.predict(X_test)

# %%
plt.scatter(linearPred,y_test)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(linearPred,y_test)
# Out:
# 2.7713026583416414e-29
